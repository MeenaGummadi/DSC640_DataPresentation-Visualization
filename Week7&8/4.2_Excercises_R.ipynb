# %% [markdown]
# # R - Plots

# %%
library('magrittr')
library('dplyr')
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
crimerate <- read.csv2(paste('crimerates-by-state-2005.csv',sep=''), header=TRUE, sep=',', fill=TRUE, stringsAsFactors=FALSE) %>% 
  dplyr::mutate(murder = as.numeric(murder),
                forcible_rape = as.numeric(forcible_rape),
                robbery = as.numeric(robbery),
                aggravated_assault = as.numeric(aggravated_assault),
                burglary = as.numeric(burglary),
                larceny_theft = as.numeric(larceny_theft),
                motor_vehicle_theft = as.numeric(motor_vehicle_theft),
                population = as.integer(population),
                total_crime = murder+
                  forcible_rape+
                  robbery+
                  aggravated_assault+
                  burglary+
                  larceny_theft+
                  motor_vehicle_theft,
                state_cont = rank(state, ties.method = 'first'))

head(crimerate)
# Out:
#   state         murder forcible_rape robbery aggravated_assault burglary
# 1 United States 5.6    31.7          140.7   291.1               726.7
# 2 Alabama       8.2    34.3          141.4   247.8               953.8
# 3 Alaska        4.8    81.1           80.9   465.1               622.5
# 4 Arizona       7.5    33.8          144.4   327.4               948.4
# 5 Arkansas      6.7    42.9           91.1   386.8              1084.6
# 6 California    6.9    26.0          176.1   317.3               693.3
#   larceny_theft motor_vehicle_theft population total_crime state_cont
# 1 2286.3        416.7               295753151  3898.8      45
# 2 2650.0        288.3                 4545049  4323.8       1
# 3 2599.1        391.0                  669488  4244.5       2
# 4 2965.2        924.4                 5974834  5351.1       3
# 5 2711.2        262.1                 2776221  4585.4       4
# 6 1916.5        712.8                35795255  3848.9       5

# %%
state_detail <- xlsx::read.xlsx2(paste("states_detail.xlsx",sep=''),sheetIndex = 1, stringsAsFactors = FALSE)
   
state_detail = rename(state_detail, "state"="full_name")
state_detail
# Out:
# java.home option:
#
# JAVA_HOME environment variable: C:\Users\meena\anaconda3\Library\lib\jvm
#
# Warning message in fun(libname, pkgname):
# "Java home setting is INVALID, it will be ignored.
# Please do NOT set it unless you want to override system settings."
#    name_caps      state          abbr region
# 1  ALABAMA        Alabama        AL   Rest of USA
# 2  ALASKA         Alaska         AK   Rest of USA
# 3  ARIZONA        Arizona        AZ   Rest of USA
# 4  ARKANSAS       Arkansas       AR   Rest of USA
# 5  CALIFORNIA     California     CA   Rest of USA
# 6  COLORADO       Colorado       CO   Rest of USA
# 7  CONNECTICUT    Connecticut    CT   Rest of USA
# 8  DELAWARE       Delaware       DE   Rest of USA
# 9  FLORIDA        Florida        FL   Rest of USA
# 10 GEORGIA        Georgia        GA   Rest of USA
# 11 HAWAII         Hawaii         HI   Rest of USA
# 12 IDAHO          Idaho          ID   Rest of USA
# 13 ILLINOIS       Illinois       IL   MidWest
# 14 INDIANA        Indiana        IN   MidWest
# 15 IOWA           Iowa           IA   MidWest
# 16 KANSAS         Kansas         KS   MidWest
# 17 KENTUCKY       Kentucky       KY   Rest of USA
# 18 LOUISIANA      Louisiana      LA   Rest of USA
# 19 MAINE          Maine          ME   Rest of USA
# 20 MARYLAND       Maryland       MD   Rest of USA
# 21 MASSACHUSETTS  Massachusetts  MA   Rest of USA
# 22 MICHIGAN       Michigan       MI   MidWest
# 23 MINNESOTA      Minnesota      MN   MidWest
# 24 MISSISSIPPI    Mississippi    MS   Rest of USA
# 25 MISSOURI       Missouri       MO   MidWest
# 26 MONTANA        Montana        MT   Rest of USA
# 27 NEBRASKA       Nebraska       NE   MidWest
# 28 NEVADA         Nevada         NV   Rest of USA
# 29 NEW HAMPSHIRE  New Hampshire  NH   Rest of USA
# 39 RHODE ISLAND   Rhode Island   RI   Rest of USA 0
# 40 SOUTH CAROLINA South Carolina SC   Rest of USA 0
# 41 SOUTH DAKOTA   South Dakota   SD   MidWest     1
# 42 TENNESSEE      Tennessee      TN   Rest of USA 0
# 43 TEXAS          Texas          TX   Rest of USA 0
# 44 UTAH           Utah           UT   Rest of USA 0
# 45 VERMONT        Vermont        VT   Rest of USA 0
# 46 VIRGINIA       Virginia       VA   Rest of USA 0
# 47 WASHINGTON     Washington     WA   Rest of USA 0
# 48 WEST VIRGINIA  West Virginia  WV   Rest of USA 0
# 49 WISCONSIN      Wisconsin      WI   MidWest     1
# 50 WYOMING        Wyoming        WY   Rest of USA 0

# %%
# Remove USA as a state and add region
crimerate_states <- crimerate %>% 
  dplyr::left_join(state_detail, by='state') %>% 
  dplyr::filter(state !='United States') %>%
  dplyr::mutate(midwest = as.integer(midwest))


crimerate_states[is.na(crimerate_states)] <- 0


head(crimerate_states)
# Out:
#   state      murder forcible_rape robbery aggravated_assault burglary
# 1 Alabama    8.2    34.3          141.4   247.8               953.8
# 2 Alaska     4.8    81.1           80.9   465.1               622.5
# 3 Arizona    7.5    33.8          144.4   327.4               948.4
# 4 Arkansas   6.7    42.9           91.1   386.8              1084.6
# 5 California 6.9    26.0          176.1   317.3               693.3
# 6 Colorado   3.7    43.4           84.6   264.7               744.8
#   larceny_theft motor_vehicle_theft population total_crime state_cont
# 1 2650.0        288.3                4545049   4323.8      1
# 2 2599.1        391.0                 669488   4244.5      2
# 3 2965.2        924.4                5974834   5351.1      3
# 4 2711.2        262.1                2776221   4585.4      4
# 5 1916.5        712.8               35795255   3848.9      5
# 6 2735.2        559.5                4660780   4435.9      6
#   name_caps  abbr region      midwest
# 1 ALABAMA    AL   Rest of USA 0
# 2 ALASKA     AK   Rest of USA 0
# 3 ARIZONA    AZ   Rest of USA 0
# 4 ARKANSAS   AR   Rest of USA 0
# 5 CALIFORNIA CA   Rest of USA 0
# 6 COLORADO   CO   Rest of USA 0

# %% [markdown]
# ## R - Scatter Plot

# %%
options(repr.plot.width = 5, repr.plot.height = 5)

# Plot
ggplot2::ggplot(data = crimerate_states) +
  ggplot2::aes(x = murder, y = forcible_rape) +
  ggplot2::geom_point(color = "#0c4c8a") +
  ggplot2::labs(title = "Correlation between forcible_rape and Murder",
       x = "Murder",
       y = "forcible_rape") +
  ggplot2::theme_grey()
# Out:
# plot without title

# %% [markdown]
# ## R - Bubble chart

# %%
# Format graph size
options(repr.plot.width = 7, repr.plot.height = 3)

# Plot
ggplot2::ggplot(data = crimerate_states) +
  ggplot2::aes(x = murder, y = forcible_rape, color = total_crime, size = population) +
  ggplot2::geom_point() +
  ggplot2::labs(title = "Relationship between Murder, forcible_rape, Total Crime and Population") +
  ggplot2::theme_classic()
# Out:
# plot without title

# %% [markdown]
# ## R - Density Plot

# %%
# For this I want to compare total crime rate of mid west states to the rest of the states
crimerate_compare <- crimerate_states[,-1]
rownames(crimerate_compare) <- crimerate_states[,1]

ggplot2::ggplot(crimerate_compare) +
  ggplot2::aes(total_crime, fill=as.factor(crimerate_compare$midwest)) +
  ggplot2::geom_density(alpha = 0.3) +
  ggplot2::labs(x='Total Crime', y='Density') +
  ggplot2::theme_classic() +
  ggplot2::guides(fill=ggplot2::guide_legend(title="Mid West flag"))
# Out:
# Warning message:
# "Use of `crimerate_compare$midwest` is discouraged. Use `midwest` instead."
# plot without title
